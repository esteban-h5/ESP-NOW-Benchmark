# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

nombre_csv = "rtt_data.csv"
print(f"archivo: {os.path.isfile(nombre_csv)}")
# Out:
# archivo: True

# %%
data = pd.read_csv(nombre_csv,index_col=False)
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RTT     185 non-null    int64
#  1   Hora    185 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.0+ KB
#    RTT      Hora
# 0    4  22:27:08
# 1   19  22:27:10
# 2    9  22:27:12
# 3   19  22:27:14
# 4    3  22:27:16

# %%
plt.plot(data["RTT"])
